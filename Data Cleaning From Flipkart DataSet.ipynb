# %%
import pandas as pd

# %%
pd.read_csv('flipkart_mobile.csv')
# Out:
#     Unnamed: 0                                         brand name  \
# 0            0            REDMI 11 Prime 5G (Meadow Green, 64 GB)
# 1            1              realme GT 8 Pro (Diary White, 512 GB)
# 2            2              OnePlus 11 5G (Eternal Green, 256 GB)
# 3            3             IQOO Z11 Lite 5G (Solar Flame, 256 GB)
# 4            4               realme P4R 5G (Silver Glare, 128 GB)
# ..         ...                                                ...
# 91          91            realme 16 Pro+ 5G (Master Grey, 256 GB)
# 92          92                  IQOO 15R 5G (Dark Knight, 256 GB)
# 93          93  Samsung Galaxy S24 5G Snapdragon (Onyx Black, ...
# 94          94              OPPO Reno16 5G (Starry White, 256 GB)
# 95          95                     Ai+ Nova 2 Neo 5G (Red, 64 GB)
#
#                    rating & review  star rating discount  \
# 0      4,687 Ratings & 262 Reviews          4.2      NaN
# ...
